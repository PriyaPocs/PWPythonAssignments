# %% [markdown]
# Consider following code to answer further questions:
#
# import pandas as pd
#
# course_name = [‘Data Science’, ‘Machine Learning’, ‘Big Data’, ‘Data Engineer’]
#  duration = [2,3,6,4]
#
# df = pd.DataFrame(data = {‘course_name’ : course_name, ‘duration’ : duration})

# %%
import pandas as pd

course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]

df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# Q1. Write a code to print the data present in the second row of the dataframe, df.
#
# Answer(Q1):

# %%
df.iloc[[1]]
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %% [markdown]
# Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?
#
# Answer(Q2):

# %% [markdown]
# loc() function:
#
# The loc() function is label based data selecting method which means that we have to pass the name of the row or column which we want to select. This method includes the last element of the range passed in it, unlike iloc(). loc() can accept the boolean data unlike iloc().
#
# iloc() function:
#
# The iloc() function is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column. This method does not include the last element of the range passed in it unlike loc(). iloc() does not accept the boolean data unlike loc().

# %%
# importing the module
import pandas as pd

# creating a sample dataframe
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
							'Mahindra', 'Maruti', 'Hyundai',
							'Renault', 'Tata', 'Maruti'],
					'Year': [2012, 2014, 2011, 2015, 2012,
							2016, 2014, 2018, 2019],
					'Kms Driven': [50000, 30000, 60000,
									25000, 10000, 46000,
									31000, 15000, 12000],
					'City': ['Gurgaon', 'Delhi', 'Mumbai',
							'Delhi', 'Mumbai', 'Delhi',
							'Mumbai', 'Chennai', 'Ghaziabad'],
					'Mileage': [28, 27, 25, 26, 28,
								29, 24, 21, 24]})

# displaying the DataFrame
display(data)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
# selecting cars with brand 'Maruti' and Mileage > 25
display(data.loc[(data.Brand == 'Maruti') & (data.Mileage > 25)])
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 4  Maruti  2012       10000   Mumbai       28

# %%
# selecting range of rows from 2 to 5
display(data.loc[2: 5])
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Delhi       26
# 4    Maruti  2012       10000  Mumbai       28
# 5   Hyundai  2016       46000   Delhi       29

# %%
# selecting 0th, 2nd, 4th, and 7th index rows
display(data.iloc[[0, 2, 4, 7]])
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 2    Tata  2011       60000   Mumbai       25
# 4  Maruti  2012       10000   Mumbai       28
# 7    Tata  2018       15000  Chennai       21

# %%
# selecting rows from 1 to 4 and columns from 2 to 4
display(data.iloc[1: 5, 2: 5])
# Out:
#    Kms Driven    City  Mileage
# 1       30000   Delhi       27
# 2       60000  Mumbai       25
# 3       25000   Delhi       26
# 4       10000  Mumbai       28

# %% [markdown]
# Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2].
# Did you observe any difference in both the outputs? If so then explain it.
#  Consider the below code to answer further questions:
#
#
# Answer(Q3):

# %%
import pandas as pd

import numpy as np

columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']

indices = [1,2,3,4,5,6]

#Creating a dataframe:

df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.598356  0.249851  0.899485  0.685271  0.566060  0.700281
# 2  0.615312  0.486447  0.015262  0.047216  0.335654  0.909534
# 3  0.930483  0.179957  0.710691  0.715187  0.667911  0.190987
# 4  0.191950  0.059425  0.115381  0.241209  0.293787  0.142057
# 5  0.730356  0.917573  0.371085  0.084454  0.065661  0.286479
# 6  0.945213  0.386976  0.537042  0.882479  0.095367  0.737192

# %%
reindex = [3,0,1,2]
new_df = df1.reindex(reindex)
new_df
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 3  0.262530  0.003813  0.506858  0.444320  0.880961  0.367492
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1  0.720788  0.198838  0.951926  0.783906  0.947610  0.102381
# 2  0.682599  0.619326  0.490621  0.390710  0.769015  0.341387

# %%
new_df.loc[2]
# Out:
# column_1    0.682599
# column_2    0.619326
# column_3    0.490621
# column_4    0.390710
# column_5    0.769015
# column_6    0.341387
# Name: 2, dtype: float64

# %%
new_df.iloc[2]
# Out:
# column_1    0.720788
# column_2    0.198838
# column_3    0.951926
# column_4    0.783906
# column_5    0.947610
# column_6    0.102381
# Name: 1, dtype: float64

# %% [markdown]
# Based on the example observation,
#
# loc() method includes the last element of the range passed in it, unlike iloc().
#
# iloc() method does not include the last element of the range passed in it unlike loc().

# %% [markdown]
# Q4. Write a code to find the following statistical measurements for the above dataframe df1:
#
# (i) mean of each and every column present in the dataframe.
#
# (ii) standard deviation of column, ‘column_2’
#
# Answer(Q4):

# %%
print('mean of column_1 = ',df1['column_1'].mean())
print('mean of column_2 = ',df1['column_2'].mean())
print('mean of column_3 = ',df1['column_3'].mean())
print('mean of column_4 = ',df1['column_4'].mean())
print('mean of column_5 = ',df1['column_5'].mean())
print('mean of column_6 = ',df1['column_6'].mean())
# Out:
# mean of column_1 =  0.5552296687661974
# mean of column_2 =  0.4166359656674589
# mean of column_3 =  0.6841139506326014
# mean of column_4 =  0.4875069994811138
# mean of column_5 =  0.6114909182492011
# mean of column_6 =  0.4992914331578491

# %%
print('std of column_2 = ',df1['column_2'].std())
# Out:
# std of column_2 =  0.2824924671867887

# %% [markdown]
# Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2.
#
# If you are getting errors in executing it then explain why.
#
# [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]
#
# Answer(Q5):

# %%
df1.loc[2,'column_2'] = "Cooper"
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.598356  0.249851  0.899485  0.685271  0.566060  0.700281
# 2  0.615312    Cooper  0.015262  0.047216  0.335654  0.909534
# 3  0.930483  0.179957  0.710691  0.715187  0.667911  0.190987
# 4  0.191950  0.059425  0.115381  0.241209  0.293787  0.142057
# 5  0.730356  0.917573  0.371085  0.084454  0.065661  0.286479
# 6  0.945213  0.386976  0.537042  0.882479  0.095367  0.737192

# %%
df1['column_2'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df1['column_2'].mean()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
# ...

# %% [markdown]
# It's throwing TypeError: unsupported operand type(s) for +: 'float' and 'str' as with the value of string "Cooper" with the other numbers, it's not possible to find the mean.All values should be numerical to find mean.

# %% [markdown]
# Q6. What do you understand about the windows function in pandas and list the types of windows functions?

# %% [markdown]
# Answer(Q6):
#
# A window function performs a calculation across a set of table rows that are somehow related to the current row. This is comparable to the type of calculation that can be done with an aggregate function.
#
# This function can be applied on a series of data. Specify the window=n argument and apply the appropriate statistical function on top of it.
#
#
# 1.Rolling window operations
#
# 2.Weighted window operations
#
# 3.Expanding window operations
#
# 4.Exponentially Weighted window

# %%
import pandas as pd
s = pd.Series(range(5))
s.rolling(window=2).sum()
# Out:
# 0    NaN
# 1    1.0
# 2    3.0
# 3    5.0
# 4    7.0
# dtype: float64

# %%
for window in s.rolling(window=2):
    print(window)
# Out:
# 0    0
# dtype: int64
# 0    0
# 1    1
# dtype: int64
# 1    1
# 2    2
# dtype: int64
# 2    2
# 3    3
# dtype: int64
# 3    3
# 4    4
# dtype: int64

# %%
s.rolling(window=2).mean()
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
s.rolling(window=2).max()
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %% [markdown]
# Q7. Write a code to print only the current month and year at the time of answering this question.
#  [Hint: Use pandas.datetime function]
#
# Answer(Q7):

# %%
import pandas as pd
# importing date class from datetime module
from datetime import date

# creating the date object of today's date
todays_date = date.today()
today = str(todays_date)

# printing todays date
print("Current date as string: ", today)
todays_date1 = pd.to_datetime(today)
print("today_date as date obj: ", today_date)


# fetching the current year, month and day of today
print("Current year:", todays_date1.year)
print("Current month:", todays_date1.month)
print("Current day:", todays_date1.day)


# As a timestamp
# Out:
# Current date:  2023-07-06
# today_date:  2023-07-06 00:00:00
# Current year: 2023
# Current month: 7
# Current day: 6

# %% [markdown]
# Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and calculates the difference between them in days, hours, and minutes using Pandas time delta. The program should prompt the user to enter the dates and display the result.
#
# Answer(Q8):

# %%
import pandas as pd
from datetime import date


str_date1 = input('Enter Date1 (in the format YYYY-MM-DD) ')
str_date2 = input('Enter Date2 (in the format YYYY-MM-DD) ')

date1 = pd.to_datetime(str_date1)
date2 = pd.to_datetime(str_date2)
# difference = date2 - date1
timedelta = pd.Timedelta(date2 - date1)
print(timedelta)
s = timedelta.seconds
h, s = divmod(s, 3600)
m, s = divmod(s, 60)
print(timedelta.days,' days ',h,' hrs ',m,' minutes ',s,' seconds')
# Out:
# Enter Date1 (in the format YYYY-MM-DD)  2023-07-01
# Enter Date2 (in the format YYYY-MM-DD)  2023-07-04 01:05:55
# 3 days 01:05:55
# 3  days  1  hrs  5  minutes  55  seconds

# %% [markdown]
# Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified column to a categorical data type. The program should prompt the user to enter the file path, column name, and category order, and then display the sorted data.
#
# Answer(Q9):

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sex_cat_order = ['female' ,'male'] 
sex_cat_data = CategoricalDtype(categories=sex_cat_order , ordered=True)
data1= pd.Series(df['Sex'], dtype= sex_cat_data)
# data1
data1.sort_values()
# Out:
# 383    female
# 218    female
# 609    female
# 216    female
# 215    female
#         ...
# 371      male
# 372      male
# 373      male
# 360      male
# 890      male
# Name: Sex, Length: 891, dtype: category
# Categories (2, object): ['female' < 'male']

# %%
survived_cat_order = [1 ,0] 
survived_cat_data = CategoricalDtype(categories=survived_cat_order , ordered=True)
data2= pd.Series(df['Survived'], dtype= survived_cat_data)
data2.sort_values()
# Out:
# 445    1
# 334    1
# 330    1
# 329    1
# 328    1
#       ..
# 372    0
# 373    0
# 374    0
# 361    0
# 890    0
# Name: Survived, Length: 891, dtype: category
# Categories (2, int64): [1 < 0]

# %% [markdown]
# Q10. Write a Python program that reads a CSV file containing sales data for different products and visualizes the data using a stacked bar chart to show the sales of each product category over time. The program should prompt the user to enter the file path and display the chart.
#
#
# Answer(Q10):

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mukulbindal/Files/main/electronics.csv")
df.columns = ['month','product','Sales']
df
# Out:
#        month          product  Sales
# 0    January  Washing Machine      7
# 1    January           Mobile     11
# 2    January               AC      0
# 3    January     Refrigerator     17
# 4   February               TV     23
# 5   February  Washing Machine      4
# 6   February           Mobile     14
# 7   February               AC      0
# 8   February     Refrigerator     12
# 9      March               TV      6
# 10     March  Washing Machine     26
# 11     March           Mobile     22
# 12     March               AC     15
# 13     March     Refrigerator      0
# 14     April               TV     12
# 15     April  Washing Machine      4
# 16     April           Mobile     28
# 17     April               AC     14
# 18     April     Refrigerator      9

# %%
pivot = pd.pivot_table(data=df, index=['product'], columns=['month'], values='Sales')
pivot
# Out:
# month            April  February  January  March
# product
# AC                14.0       0.0      0.0   15.0
# Mobile            28.0      14.0     11.0   22.0
# Refrigerator       9.0      12.0     17.0    0.0
# TV                12.0      23.0      NaN    6.0
# Washing Machine    4.0       4.0      7.0   26.0

# %%
ax = pivot.plot.bar(stacked=True, color =['lightseagreen', 'tomato','blue','yellow'], figsize=(8,6))
ax.set_title('Sales of each product category over time', fontsize=20)
ax.set_ylim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and displays the results in a table.
# The program should do the followingM
# I PrompttheusertoenterthefilepathoftheCSVfilecontainingthestudentdataR I ReadtheCSVfileintoaPandasDataFrameR
# I Calculatethemean,median,andmodeofthetestscoresusingPandastoolsR
# I Displaythemean,median,andmodeinatable.
#
# Assume the CSV file contains the following columnsM
# I StudentID:TheIDofthestudentR
# I TestScore:Thescoreofthestudent'stest.
# Example usage of the program:
#
# Enter the file path of the CSV file containing the student data: student_data.csv
#
#
# +-----------+--------+
#  | Statistic | Value |
#  +-----------+--------+
#  |Mean |79.6 |
#
# |Median |82 |
#
# |Mode |85,90|
#  +-----------+--------+
#
#
# Assume that the CSV file student_data.csv contains the following data:
#  Student ID,Test Score
#
# 1,85
#
# 2,90
#
# 3,80
#  4,75
#  5,85
#  6,82
#  7,78
#  8,85
#  9,90
#  10,85
#
#
# The program should calculate the mean, median, and mode of the test scores and display the results in a table.
#
#
# Answer(Q11):

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/PriyaPocs/PWPythonAssignments/main/student_data.csv")
df
# Out:
#    StudentID  TestScore
# 0          1         85
# 1          2         90
# 2          3         80
# 3          4         75
# 4          5         85
# 5          6         82
# 6          7         78
# 7          8         85
# 8          9         90
# 9         10         85

# %%
print('-'*25)
print('| Statistic | Value |')
print('-'*25)
print('|Mean |',df['TestScore'].mean(),'|')
print('|Median |',df['TestScore'].median(),'|')
freq_mode1 = df['TestScore'].mode().iat[0]
# print(freq_mode1)
df2 = (df[df.TestScore != freq_mode1])
freq_mode2 = df2['TestScore'].mode().iat[0]
# print(freq_mode2)
print('|Mode |',freq_mode1,'|',freq_mode2,'|')
print('-'*25)
# Out:
# -------------------------
# | Statistic | Value |
# -------------------------
# |Mean | 83.5 |
# |Median | 85.0 |
# |Mode | 85 | 90 |
# -------------------------
