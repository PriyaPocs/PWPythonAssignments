# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?
#
#
# Answer(Q1):

# %%
# !pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure , output_file, show
from bokeh.sampledata.iris import flowers

flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')

p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.circle(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div id="b4722a43-5110-437b-a0ae-dd018637cfc7" data-root-id="p1002" style="display: contents;"></div>

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
#
#
# Answer(Q2):
#
# Glyphs are the building blocks of Bokeh visualizations. A glyph is a vectorized graphical shape or marker that is used to represent your data. Here are a few different categories of glyphs.They can be a marker—shapes like circles, diamonds, squares, and triangles.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_file

# prepare some data
x = [1, 2, 4, 6, 7]
y = [7, 6, 3, 9, 10]

# create a new plot with figure function
p = figure(title="Circle Glyph", outer_width=450, outer_height=400)

# create circle glyph
p.circle(x=x, y=y, size=25, fill_color="red")
p.circle_cross(x=[2, 4, 6, 8], y=[5, 8, 9, 11], size=25,
			fill_color="blue", fill_alpha=0.3, line_width=2)
p.circle_x(x=[4, 7, 2, 6], y=[7, 2, 4, 9], size=25,
		fill_color="green", fill_alpha=0.6, line_width=2)

# show the results
output_file('circle.html')
show(p)
# Out:
#   <div id="208b4720-1cda-4b57-b54f-078ff899487f" data-root-id="p1297" style="display: contents;"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?
#
#
# Answer(Q3):

# %%
output_file('test.html')

p = figure(title = 'X Vs Y')
p.xaxis.axis_label = "X Values"
p.yaxis.axis_label = "Y Values"
# prepare some data
x = [1, 2, 4, 6, 7]
y = [7, 6, 3, 9, 10]
p.circle(x , y)
show(p)
# Out:
#   <div id="3acc9d82-9b6c-4111-923a-60fcaaa48f13" data-root-id="p1851" style="display: contents;"></div>

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in real time?
#
# Answer(Q4):
#
# Bokeh server makes it easy to create interactive web applications that connect front-end UI events to running Python code. Bokeh creates high-level Python models, such as plots, ranges, axes, and glyphs, and then converts these objects to JSON to pass them to its client library, BokehJS.

# %%
# importing the modules
from bokeh.plotting import figure, output_file, show

# file to save the model
output_file("gfg.html")
		
# instantiating the figure object
graph = figure(title = "Bokeh Hiding Glyphs")

# plotting the graph
graph.vbar(x = 1, top = 5,
		width = 1, color = "violet",
		legend_label = "Violet Bar")
graph.vbar(x = 2, top = 5,
		width = 1, color = "green",
		legend_label = "Green Bar")
graph.vbar(x = 3, top = 5,
		width = 1, color = "yellow",
		legend_label = "Yellow Bar")
graph.vbar(x = 4, top = 5,
		width = 1, color = "red",
		legend_label = "Red Bar")

# enable hiding of the glyphs
graph.legend.click_policy = "hide"

# displaying the model
show(graph)
# Out:
#   <div id="e36a50e1-3166-4ce2-bc58-c3bfbe6c37f9" data-root-id="p1845" style="display: contents;"></div>

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?
#
# Answer(Q5):
# Bokeh Flask App link:
#
# https://github.com/PriyaPocs/BokekFlaskApp
